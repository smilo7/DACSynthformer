# %% [markdown]
# ### chaptGPT specs
#
# A decoder-only transformer in pytorch to predict 'next output' at each time step.
#
# Each time step t is represented by a vector of n=4 tokens from the Descript DAC encoder.
# The length of the sequence (context window) is Ti=86 for inference, and Tt=8*Ti for training. That is, the context window for training is 8 times the length of the context window for inference.
# The attention is "causal", looking only back in time, and the maximum look-back time for the attention blocks is Ti (even when the sequence is longer during training). That is, the masking matrix is *banded* - triangular to be causal, and limited in lookback which results in a diagonal band). This prevents much of the training on shortened context that happens when tokens are near the beginning of traning examples.
#
# The size of the vocabulary (the number of descrete values in each codebook) for each of the n tokens is V=1024.
#
# The dataloader will as is usual, supply batches in triplets  (input, target, conditioning info) where the size of each input and output is Tt*n (the sequence length times the number of tokens at each time step). The tokens are indexes for the vocabulary in the range of (0, V-1). The targets are shifted relative to the input sequence by 1 as is typical for networks the learn to predict the output for the next time step.
#
# The first layer in the architecture will be a learnable "multiembedding" layer that embeds each of the 4 tokens at each time step as an m-dimensional vector. The n m-dimensional vectors are concatenated to provide the n*m dimensional input embeddings for the transformer blocks at each time step.
#
# A positional code is is added to the K and Q matricies in each Transformer block using Rotary Position Embedding (RoPE).
#
# We use a stack of b transformer blocks that are standard (using layer norms, a relu for activation, and a forward expansion factor of 4 form the linear layer). Each transformer block consumes and produces a context window length sequence of m*n dimensional vectors.
#
# After the last transformer block, there is a linear layer that maps the m*n dimensional vectors to the output size which is V*n (the vocabulary size time the number of tokens stacked at each time step). These are the logits that will be fed to the softmax functions (one for each of the n to kens) that provide the probability distribtion across the vocabulary set. We use the criterion nn.CrossEntropyLoss() for computing the loss using the targets provided by the dataloader, and Adam for the optimizer.
#
# Again, at inference time, the fixed-length context window is shorter than the training sequence window length, and equal to the maximum look-back time of the attention blocks. The inference process takes the output produced at each time step (a stack of n tokens), and shift them in to a sliding window that is used for input for the next time step. The length of the sequences generated during inference is arbitrary and should be settable with a parameter.

# %% [markdown]
# <div style="width: 100%; height: 20px; background-color: black;"></div>

# %% [markdown]
# ## Parameters

# %%
paramfile = 'params_med_mine_params_added.yaml' # 'params.yaml' #
DEVICE='cpu' ##''cuda'
start_epoch=0 # to start from a previous training checkpoint, otherwise must be 0
verboselevel=0

# %% [markdown]
# <div style="width: 100%; height: 20px; background-color: black;"></div>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import math
import time

import numpy as np

# and for creating a custom dataset and loader:
from torch.utils.data import DataLoader
import os
import yaml
import shutil

from utils.utils import generate_mask, save_model, load_model, writeDACFile, interpolate_vectors
from DACTransformer.RopeCondDACTransformer import RopeCondDACTransformer

from dataloader.dataset import CustomDACDataset

# %%
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ### <font color='blue'> Derived parameters </font>

# %%
# Training data dir

# Load YAML file
with open(paramfile, 'r') as file:
    params = yaml.safe_load(file)

data_dir = params['data_dir']
data_frames =  params['data_frames']
validator_data_dir = params['validator_data_dir']
validator_data_frames = params['validator_data_frames']

# Create an instance of the dataset
dataset = CustomDACDataset(data_dir=data_dir, metadata_excel=data_frames, transforms=None)

# ---------     for the transformer  --------------#
vocab_size = params['vocab_size']
num_tokens = params['num_tokens']

cond_classes = dataset.get_num_classes() # 0
cond_params = params['cond_params']
cond_size = cond_classes + cond_params # num_classes + num params - not a FREE parameter!

#embed_size = params['tblock_input_size'] -cond_size # 240 #32  # embed_size +cond_size must be divisible by num_heads and by num tokens
embed_size = params['model_size']  # embed_size  must be divisible by num_heads and by num tokens
print(f'embed_size is {embed_size}')

Ti = params['Ti']
Tt = params['Tt']
batch_size = params['batch_size']

sequence_length = Tt  # For training

num_layers = params['num_layers']
num_heads = params['num_heads']
forward_expansion = params['forward_expansion']
dropout_rate = params['dropout_rate']
learning_rate = params['learning_rate']
num_epochs=params['num_epochs']

experiment_name=params['experiment'] 
outdir = 'runs' + '/' + experiment_name
basefname= 'out' + '.e' + str(embed_size) + '.l' + str(num_layers) + '.h' + str(num_heads) 

ErrorLogRate = params['ErrorLogRate'] #10
checkpoint_interval = params['checkpoint_interval']



TransformerClass =  globals().get(params['TransformerClass'])  

print(f"using TransformerClass = {params['TransformerClass']}") 
print(f'basefname = {basefname}')
print(f'outdir = {outdir}')

###########################################################################
# Ensure the destination directory exists
#destination_dir = os.path.dirname(outdir + '/' + paramfile)
#if not os.path.exists(destination_dir):
#    os.makedirs(destination_dir)
    
if not os.path.exists(outdir):
    os.makedirs(outdir)
shutil.copy(paramfile, outdir + '/params.yaml')  # copy whatever paramfile was used to outdir and name it params.yaml
# Out:
# embed_size is 256
# using TransformerClass = RopeCondDACTransformer
# basefname = out.e256.l2.h8
# outdir = runs/med_test_mine_01_params_added
# 'runs/med_test_mine_01_params_added/params.yaml'

# %% [markdown]
# ### <font color='blue'> Set up cuda.
# Without it, training runs about 10 times slower
# </font>

# %%
if DEVICE == 'cuda' :
    torch.cuda.device_count()
    torch.cuda.get_device_properties(0).total_memory/1e9

    device = torch.device(DEVICE) # if the docker was started with --gpus all, then can choose here with cuda:0 (or cpu)
    torch.cuda.device_count()
    print(f'memory on cuda 0 is  {torch.cuda.get_device_properties(0).total_memory/1e9}')
else :
    device=DEVICE
device
# Out:
# 'cpu'

# %% [markdown]
# ### <font color='blue'> Load data
# </font>

# %%
# Create a DataLoader
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

#Validator data set
if validator_data_dir != None :
    validator_dataset=CustomDACDataset(data_dir=validator_data_dir, metadata_excel=validator_data_frames)
    validator_dataloader= DataLoader(validator_dataset, batch_size=batch_size, shuffle=True)

#---------------------------------------------------------------
# Test data dir
for batch_idx, (inputs, targets, cvect) in enumerate(dataloader):
    #pass
    # Your training code here
    # inputs: batch of input data of shape [batch_size, N, T-1]
    # targets: corresponding batch of target data of shape [batch_size, N, T-1]
    
    if (batch_idx == 0) : 
        print(f"Batch {batch_idx + 1}")
        print(f"Inputs shape: {inputs.shape}")
        print(f"Targets shape: {targets.shape}")
        print(f"cvect shape: {cvect.shape}")
        print(f'cevect is {cvect}')
# Out:
# Batch 1
# Inputs shape: torch.Size([4, 430, 4])
# Targets shape: torch.Size([4, 430, 4])
# cvect shape: torch.Size([4, 6])
# cevect is tensor([[0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 1.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.2000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.3000]])

# %% [markdown]
# ### <font color='blue'> Make the mask
# </font>

# %%
mask = generate_mask(Tt, Ti).to(device)
print(f'Mask.shape is {mask.shape}')
mask
# Out:
# Mask.shape is torch.Size([430, 430])
# tensor([[0., -inf, -inf,  ..., -inf, -inf, -inf],
#         [0., 0., -inf,  ..., -inf, -inf, -inf],
#         [0., 0., 0.,  ..., -inf, -inf, -inf],
#         ...,
#         [-inf, -inf, -inf,  ..., 0., -inf, -inf],
#         [-inf, -inf, -inf,  ..., 0., 0., -inf],
#         [-inf, -inf, -inf,  ..., 0., 0., 0.]])

# %%
# Instantiate model, put it on the device
#model = TransformerDecoder(embed_size, num_layers, num_heads, forward_expansion, dropout_rate, Tt, num_tokens, vocab_size).to(device)
print(f'Creating model with embed_size={embed_size}, cond_size={cond_size}')

if start_epoch == 0 : 
    model = TransformerClass(embed_size, num_layers, num_heads, forward_expansion, dropout_rate, Tt, cond_classes, num_tokens, vocab_size, cond_size, verboselevel).to(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
else:
    checkpoint_path = outdir+"/"+basefname+"_chkpt_"+str(start_epoch).zfill(4) +".pth"
    print(f'in train, start_epoch = {start_epoch} and checkpoint_path = {checkpoint_path}')
    assert os.path.exists(checkpoint_path), f"{checkpoint_path} does not exist."
    if start_epoch != 0 and checkpoint_path and os.path.exists(checkpoint_path):
        print(f"Loading and creating model from {checkpoint_path}")       
        # Restore model weights
        model, optimizer, _, vocab_size, num_tokens, cond_size = load_model(checkpoint_path,  TransformerClass, device)
        #best_metric = checkpoint['best_metric']  # If you're tracking performance      
        print(f"Resuming from epoch {start_epoch}")
   
criterion = nn.CrossEntropyLoss()
# Count the number of parameters
num_params = sum(p.numel() for p in model.parameters())
print(f'Total number of parameters: {num_params}')

# Initialize SummaryWriter for tensorboard 
writer = SummaryWriter(outdir)
# Out:
# Creating model with embed_size=256, cond_size=6
#  ------------- embed_dim (256) must be divisible by num_heads (8)
# Setting up MultiEmbedding with vocab_size= 1024, embed_size= 256, num_codebooks= 4
# Setting up RotaryPositionalEmbedding with embed_size= 256, max_len= 430
# Total number of parameters: 2503680

# %% [markdown]
# <div style="width: 100%; height: 20px; background-color: black;"></div>

# %% [markdown]
# # <font color='blue'> Train !!
# </font>

# %% [markdown]
# ### loss is average CE across all output tokens
#
# $$
# L = \frac{1}{N} \sum_{n=1}^{N} \text{CE}(x_n, y_n)
# $$

# %%
def train(model, optimizer, dataloader, num_epochs, device, outdir, basefname, start_epoch=0, checkpoint_path=None):
    t0 = time.time()
    max_epoch = start_epoch + num_epochs
    for epoch in range(start_epoch, max_epoch):
        torch.cuda.empty_cache()
        model.train()
        for batch_idx, (input_data, target_data, cond_data) in enumerate(dataloader):
            if verboselevel > 5 :
                print(f' ---- submitting batch with input_data={input_data.shape}, target_data={target_data.shape}, cond_data={cond_data.shape}')
            #print(f"b{batch_idx} ", end='')
            optimizer.zero_grad()
    
            # Move inputs and targets to the device
            input_data, target_data, cond_data = input_data.to(device), target_data.to(device), cond_data.to(device)
            
            if cond_size==0 :  #Ignore conditioning data
                cond_expanded=None
            else : 
                # for dataset exammples, expand the conditioning info across all time steps before passing to models
                cond_expanded = cond_data.unsqueeze(1).expand(-1, input_data.size(1), -1)
            
            #print(f'    after loading a batch,  input_data.shape is {input_data.shape}, and cond_data.shape is {cond_data.shape}')
            #print(f'    after loading a batch,  cond_expanded.shape is {cond_expanded.shape}')
            #print(f'    after loading a batch,  mask.shape is {mask.shape}')
            #print(f' model={model}')
            
            # torch.Size([batch_size, seq_len, num_tokens, vocab_size])
            output = model(input_data, cond_expanded, mask)
        
            if verboselevel > 5 :
                print(f' TTTTTTTT after training, output shape ={output.shape}, torch.Size([batch_size, seq_len, num_tokens, vocab_size])')
                print(f' TTTTTTTT Passing to CRITERION with , output.reshape(-1, vocab_size) = {output.reshape(-1, vocab_size).shape} and target_data.reshape(-1) = {target_data.reshape(-1).shape}' )
    
            ##  this works, but is too verbose >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            ##      # Original shape: (batch_size, seq_len, num_tokens, vocab_size)
            ##      output = output.reshape(batch_size, sequence_length * num_tokens, vocab_size)
            ##      # Original shape: (batch_size, seq_len, num_tokens)
            ##      targets = targets.reshape(batch_size, sequence_length * num_tokens)
            ##      loss = criterion(output.permute(0, 2, 1), targets) 
            
            ##  more succinct <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
            #   Computes the CE for each token separately, and then averages them to get the loss.
            #loss = criterion(output.reshape(-1, vocab_size), target_data.reshape(-1)) # collapses all target_data dimensions into a single dimension
            loss = criterion(output.reshape(-1, vocab_size), target_data.reshape(-1).long())
            ## <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
            
            loss.backward()
            optimizer.step()
        if (epoch+1) % ErrorLogRate == 0:
            print(f'EPOCH {epoch+1}  (with max {max_epoch}), ', end='')
            print(f'loss: {loss}')
            # Log the loss to TensorBoard
            writer.add_scalar('Loss/train', loss, epoch)
            
            if validator_data_dir != None :
                model.eval()
                with torch.no_grad():
                    val_loss = 0
                    for val_inputs, val_targets, cond_data in validator_dataloader:
                        val_inputs, val_targets, cond_data = val_inputs.to(device), val_targets.to(device), cond_data.to(device)
                        
                        if cond_size==0 :  #Ignore conditioning data
                            cond_expanded=None
                        else: 
                            # for dataset exammples, expand the conditioning info across all time steps before passing to models
                            cond_expanded = cond_data.unsqueeze(1).expand(-1, input_data.size(1), -1)
    
                        
                        val_outputs = model(val_inputs,cond_expanded, mask)
                        
                        val_loss += criterion(val_outputs.reshape(-1, vocab_size), val_targets.reshape(-1).long()) # collapses all target_data dimensions into a single dimension
                        #val_loss += criterion(val_outputs, val_targets).item()
    
                print(f'Validation Loss: {val_loss / len(validator_dataloader)}')
                writer.add_scalar('Loss/validation', val_loss / len(validator_dataloader), epoch)
    
                t1 = time.time()
                train_time = t1-t0
                print(f'train time for {epoch-start_epoch+1} epochs, was {train_time}' )
                print(f'')
                
        if (epoch+1) % checkpoint_interval == 0:
            lastbasename = outdir+"/"+basefname+"_chkpt_"+str(epoch+1).zfill(4)
            print(f'EPOCH {epoch+1} save model to : {lastbasename}.pth')
            print(f'')
            save_model(model, optimizer, Ti,  lastbasename +".pth")
        
    
    t1 = time.time()
    train_time = t1-t0
    print(f'train time for {num_epochs} epochs, was {train_time}' )
    print(f'loss  =  {loss}' )
    
## -----------------------------------------------------------------------------------
## OK, let's do it!
train(model, optimizer, dataloader, num_epochs, device, outdir, basefname, start_epoch)
# Out:
# EPOCH 2  (with max 500), loss: 6.789986610412598
# Validation Loss: 6.744317531585693
# train time for 2 epochs, was 0.6068398952484131
#
# EPOCH 4  (with max 500), loss: 6.737664222717285
# Validation Loss: 6.4809980392456055
# train time for 4 epochs, was 1.2024645805358887
#
# EPOCH 6  (with max 500), loss: 6.407008647918701
# Validation Loss: 6.185939788818359
# train time for 6 epochs, was 1.7749462127685547
#
# EPOCH 8  (with max 500), loss: 6.38615608215332
# Validation Loss: 5.8951735496521
# train time for 8 epochs, was 2.348107099533081
#
# EPOCH 10  (with max 500), loss: 5.490923881530762
# Validation Loss: 5.678787708282471
# train time for 10 epochs, was 2.928877830505371
#
# EPOCH 12  (with max 500), loss: 5.877110958099365
# Validation Loss: 5.455728530883789
# train time for 12 epochs, was 3.532345771789551
#
# EPOCH 14  (with max 500), loss: 5.2006754875183105
# Validation Loss: 5.337235450744629
# train time for 14 epochs, was 4.130362272262573
#
# EPOCH 16  (with max 500), loss: 5.7386651039123535
# Validation Loss: 5.154659271240234
# train time for 16 epochs, was 4.746440410614014
#
# EPOCH 18  (with max 500), loss: 5.3733906745910645
# Validation Loss: 4.94366455078125
# train time for 18 epochs, was 5.380719423294067
#
# EPOCH 20  (with max 500), loss: 5.21690559387207
# Validation Loss: 4.609672546386719
# train time for 20 epochs, was 6.015483140945435
#
# EPOCH 22  (with max 500), loss: 4.3457536697387695
# Validation Loss: 4.4153852462768555
# train time for 22 epochs, was 6.622905731201172
#
# EPOCH 24  (with max 500), loss: 4.584072113037109
# Validation Loss: 4.052492618560791
# train time for 24 epochs, was 7.26852822303772
#
# EPOCH 26  (with max 500), loss: 4.010490894317627
# Validation Loss: 3.808490753173828
# train time for 26 epochs, was 7.886064291000366
#
# EPOCH 28  (with max 500), loss: 4.09113883972168
# Validation Loss: 3.4322476387023926
# train time for 28 epochs, was 8.50248098373413
#
# EPOCH 30  (with max 500), loss: 3.7808449268341064
# Validation Loss: 3.130270004272461
# train time for 30 epochs, was 9.119739532470703
#
# EPOCH 32  (with max 500), loss: 3.25414776802063
# Validation Loss: 2.7641501426696777
# train time for 32 epochs, was 9.733262300491333
#
# EPOCH 34  (with max 500), loss: 2.9559478759765625
# Validation Loss: 2.4368836879730225
# train time for 34 epochs, was 10.34807014465332
#
# EPOCH 36  (with max 500), loss: 2.8234169483184814
# Validation Loss: 2.1067421436309814
# train time for 36 epochs, was 10.96489953994751
#
# EPOCH 38  (with max 500), loss: 2.5888092517852783
# Validation Loss: 1.8120369911193848
# train time for 38 epochs, was 11.545574188232422
#
# EPOCH 40  (with max 500), loss: 2.198193311691284
# Validation Loss: 1.5563557147979736
# train time for 40 epochs, was 12.13204836845398
#
# EPOCH 42  (with max 500), loss: 2.078993082046509
# Validation Loss: 1.325394630432129
# train time for 42 epochs, was 12.750439882278442
#
# EPOCH 44  (with max 500), loss: 1.7732174396514893
# Validation Loss: 1.108841061592102
# train time for 44 epochs, was 13.466914415359497
#
# EPOCH 46  (with max 500), loss: 1.5947189331054688
# Validation Loss: 0.9314765930175781
# train time for 46 epochs, was 14.080122470855713
#
# EPOCH 48  (with max 500), loss: 1.6394864320755005
# Validation Loss: 0.7525861263275146
# train time for 48 epochs, was 14.75429081916809
#
# EPOCH 50  (with max 500), loss: 1.1890876293182373
# Validation Loss: 0.6372820138931274
# train time for 50 epochs, was 15.498896360397339
#
# EPOCH 50 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0050.pth
#
# EPOCH 52  (with max 500), loss: 1.1328625679016113
# Validation Loss: 0.5222471356391907
# train time for 52 epochs, was 16.368423461914062
#
# EPOCH 54  (with max 500), loss: 0.9692941904067993
# Validation Loss: 0.44953441619873047
# train time for 54 epochs, was 17.061721086502075
#
# EPOCH 56  (with max 500), loss: 1.0240840911865234
# Validation Loss: 0.37679314613342285
# train time for 56 epochs, was 17.689277410507202
#
# EPOCH 58  (with max 500), loss: 0.7807485461235046
# Validation Loss: 0.2774370014667511
# train time for 58 epochs, was 18.302870988845825
#
# EPOCH 60  (with max 500), loss: 0.7312623262405396
# Validation Loss: 0.2303716540336609
# train time for 60 epochs, was 18.903472423553467
#
# EPOCH 62  (with max 500), loss: 0.6595432758331299
# Validation Loss: 0.18053753674030304
# train time for 62 epochs, was 19.555248737335205
#
# EPOCH 64  (with max 500), loss: 0.6680177450180054
# Validation Loss: 0.15260568261146545
# train time for 64 epochs, was 20.15849542617798
#
# EPOCH 66  (with max 500), loss: 0.472415030002594
# Validation Loss: 0.12291856110095978
# train time for 66 epochs, was 20.767346143722534
#
# EPOCH 68  (with max 500), loss: 0.5286685228347778
# Validation Loss: 0.10386241972446442
# train time for 68 epochs, was 21.37449884414673
#
# EPOCH 70  (with max 500), loss: 0.5616512894630432
# Validation Loss: 0.08446388691663742
# train time for 70 epochs, was 22.028960466384888
#
# EPOCH 72  (with max 500), loss: 0.41199102997779846
# Validation Loss: 0.0675998330116272
# train time for 72 epochs, was 22.709613800048828
#
# EPOCH 74  (with max 500), loss: 0.47265899181365967
# Validation Loss: 0.05687413364648819
# train time for 74 epochs, was 23.387502431869507
#
# EPOCH 76  (with max 500), loss: 0.4372064769268036
# Validation Loss: 0.04617726057767868
# train time for 76 epochs, was 24.066171407699585
#
# EPOCH 78  (with max 500), loss: 0.3357282876968384
# Validation Loss: 0.03680231422185898
# train time for 78 epochs, was 24.744011640548706
#
# EPOCH 80  (with max 500), loss: 0.36922183632850647
# Validation Loss: 0.03250149264931679
# train time for 80 epochs, was 25.523261308670044
#
# EPOCH 82  (with max 500), loss: 0.2347191572189331
# Validation Loss: 0.02649196982383728
# train time for 82 epochs, was 26.179972887039185
#
# EPOCH 84  (with max 500), loss: 0.27036941051483154
# Validation Loss: 0.024616755545139313
# train time for 84 epochs, was 26.82312321662903
#
# EPOCH 86  (with max 500), loss: 0.23979352414608002
# Validation Loss: 0.018606461584568024
# train time for 86 epochs, was 27.382185220718384
#
# EPOCH 88  (with max 500), loss: 0.21536988019943237
# Validation Loss: 0.016355227679014206
# train time for 88 epochs, was 27.99181056022644
#
# EPOCH 90  (with max 500), loss: 0.24379080533981323
# Validation Loss: 0.014685689471662045
# train time for 90 epochs, was 28.625285148620605
#
# EPOCH 92  (with max 500), loss: 0.22627881169319153
# Validation Loss: 0.011577961966395378
# train time for 92 epochs, was 29.259958505630493
#
# EPOCH 94  (with max 500), loss: 0.17009824514389038
# Validation Loss: 0.010632987134158611
# train time for 94 epochs, was 29.896535396575928
#
# EPOCH 96  (with max 500), loss: 0.19150875508785248
# Validation Loss: 0.009045042097568512
# train time for 96 epochs, was 30.4847149848938
#
# EPOCH 98  (with max 500), loss: 0.17190520465373993
# Validation Loss: 0.00768814142793417
# train time for 98 epochs, was 31.045175790786743
#
# EPOCH 100  (with max 500), loss: 0.18712377548217773
# Validation Loss: 0.006969315931200981
# train time for 100 epochs, was 31.668030977249146
#
# EPOCH 100 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0100.pth
#
# EPOCH 102  (with max 500), loss: 0.14197176694869995
# Validation Loss: 0.0060203708708286285
# train time for 102 epochs, was 32.293822050094604
#
# EPOCH 104  (with max 500), loss: 0.13233770430088043
# Validation Loss: 0.006384798791259527
# train time for 104 epochs, was 32.856475591659546
#
# EPOCH 106  (with max 500), loss: 0.13959118723869324
# Validation Loss: 0.005123398266732693
# train time for 106 epochs, was 33.4265193939209
#
# EPOCH 108  (with max 500), loss: 0.12496503442525864
# Validation Loss: 0.004243096336722374
# train time for 108 epochs, was 33.98704147338867
#
# EPOCH 110  (with max 500), loss: 0.149766743183136
# Validation Loss: 0.003949146252125502
# train time for 110 epochs, was 34.54612708091736
#
# EPOCH 112  (with max 500), loss: 0.14586620032787323
# Validation Loss: 0.003510219044983387
# train time for 112 epochs, was 35.11406445503235
#
# EPOCH 114  (with max 500), loss: 0.11944463849067688
# Validation Loss: 0.003265486564487219
# train time for 114 epochs, was 35.67116641998291
#
# EPOCH 116  (with max 500), loss: 0.11182327568531036
# Validation Loss: 0.0029786040540784597
# train time for 116 epochs, was 36.26182293891907
#
# EPOCH 118  (with max 500), loss: 0.09963954985141754
# Validation Loss: 0.0027097875718027353
# train time for 118 epochs, was 36.896923780441284
#
# EPOCH 120  (with max 500), loss: 0.1211092546582222
# Validation Loss: 0.002369954250752926
# train time for 120 epochs, was 37.50453066825867
#
# EPOCH 122  (with max 500), loss: 0.11244369298219681
# Validation Loss: 0.002403438091278076
# train time for 122 epochs, was 38.146111726760864
#
# EPOCH 124  (with max 500), loss: 0.08768691122531891
# Validation Loss: 0.0022738261613994837
# train time for 124 epochs, was 38.75134563446045
#
# EPOCH 126  (with max 500), loss: 0.11092472821474075
# Validation Loss: 0.0019494110019877553
# train time for 126 epochs, was 39.389825105667114
#
# EPOCH 128  (with max 500), loss: 0.08611893653869629
# Validation Loss: 0.0017157152760773897
# train time for 128 epochs, was 40.019690990448
#
# EPOCH 130  (with max 500), loss: 0.08286997675895691
# Validation Loss: 0.0017667030915617943
# train time for 130 epochs, was 40.66473960876465
#
# EPOCH 132  (with max 500), loss: 0.0717746689915657
# Validation Loss: 0.001478087855502963
# train time for 132 epochs, was 41.32963991165161
#
# EPOCH 134  (with max 500), loss: 0.08308853954076767
# Validation Loss: 0.0013802319299429655
# train time for 134 epochs, was 41.9615113735199
#
# EPOCH 136  (with max 500), loss: 0.06828358769416809
# Validation Loss: 0.001294548623263836
# train time for 136 epochs, was 42.56156325340271
#
# EPOCH 138  (with max 500), loss: 0.07954999804496765
# Validation Loss: 0.0011942134005948901
# train time for 138 epochs, was 43.20645785331726
#
# EPOCH 140  (with max 500), loss: 0.0757603645324707
# Validation Loss: 0.0011358705814927816
# train time for 140 epochs, was 43.8316535949707
#
# EPOCH 142  (with max 500), loss: 0.06825059652328491
# Validation Loss: 0.0010946444235742092
# train time for 142 epochs, was 44.44099545478821
#
# EPOCH 144  (with max 500), loss: 0.07269202172756195
# Validation Loss: 0.0010403016349300742
# train time for 144 epochs, was 45.07054924964905
#
# EPOCH 146  (with max 500), loss: 0.05012824013829231
# Validation Loss: 0.0009757209336385131
# train time for 146 epochs, was 45.658961057662964
#
# EPOCH 148  (with max 500), loss: 0.07393349707126617
# Validation Loss: 0.0009441169095225632
# train time for 148 epochs, was 46.22960329055786
#
# EPOCH 150  (with max 500), loss: 0.0655905231833458
# Validation Loss: 0.0008591783698648214
# train time for 150 epochs, was 46.80062747001648
#
# EPOCH 150 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0150.pth
#
# EPOCH 152  (with max 500), loss: 0.07244272530078888
# Validation Loss: 0.000772241794038564
# train time for 152 epochs, was 47.4589524269104
#
# EPOCH 154  (with max 500), loss: 0.05966523662209511
# Validation Loss: 0.0007371540414169431
# train time for 154 epochs, was 48.11105179786682
#
# EPOCH 156  (with max 500), loss: 0.05757972598075867
# Validation Loss: 0.0007354104891419411
# train time for 156 epochs, was 48.7053165435791
#
# EPOCH 158  (with max 500), loss: 0.04304182156920433
# Validation Loss: 0.0006626573740504682
# train time for 158 epochs, was 49.34509086608887
#
# EPOCH 160  (with max 500), loss: 0.05453620105981827
# Validation Loss: 0.00065163045655936
# train time for 160 epochs, was 49.90300250053406
#
# EPOCH 162  (with max 500), loss: 0.05244163051247597
# Validation Loss: 0.0005824173567816615
# train time for 162 epochs, was 50.44321846961975
#
# EPOCH 164  (with max 500), loss: 0.058241359889507294
# Validation Loss: 0.0005731536075472832
# train time for 164 epochs, was 51.00862717628479
#
# EPOCH 166  (with max 500), loss: 0.05030946806073189
# Validation Loss: 0.0005533070652745664
# train time for 166 epochs, was 51.57425498962402
#
# EPOCH 168  (with max 500), loss: 0.044854696840047836
# Validation Loss: 0.0004785715718753636
# train time for 168 epochs, was 52.16116952896118
#
# EPOCH 170  (with max 500), loss: 0.04262075945734978
# Validation Loss: 0.0004989273729734123
# train time for 170 epochs, was 52.78618788719177
#
# EPOCH 172  (with max 500), loss: 0.044840723276138306
# Validation Loss: 0.0004811648395843804
# train time for 172 epochs, was 53.35238862037659
#
# EPOCH 174  (with max 500), loss: 0.04940246045589447
# Validation Loss: 0.0004272725200280547
# train time for 174 epochs, was 53.89930176734924
#
# EPOCH 176  (with max 500), loss: 0.04143096134066582
# Validation Loss: 0.0004027474205940962
# train time for 176 epochs, was 54.449774503707886
#
# EPOCH 178  (with max 500), loss: 0.048077456653118134
# Validation Loss: 0.00042656727600842714
# train time for 178 epochs, was 54.995195388793945
#
# EPOCH 180  (with max 500), loss: 0.043509792536497116
# Validation Loss: 0.00037084915675222874
# train time for 180 epochs, was 55.5340359210968
#
# EPOCH 182  (with max 500), loss: 0.039071302860975266
# Validation Loss: 0.0003553304122760892
# train time for 182 epochs, was 56.10006332397461
#
# EPOCH 184  (with max 500), loss: 0.044139109551906586
# Validation Loss: 0.00034306710585951805
# train time for 184 epochs, was 56.67222356796265
#
# EPOCH 186  (with max 500), loss: 0.04041928052902222
# Validation Loss: 0.0003266566782258451
# train time for 186 epochs, was 57.230334520339966
#
# EPOCH 188  (with max 500), loss: 0.04025743156671524
# Validation Loss: 0.00034269067691639066
# train time for 188 epochs, was 57.79314303398132
#
# EPOCH 190  (with max 500), loss: 0.038384683430194855
# Validation Loss: 0.000326415611198172
# train time for 190 epochs, was 58.38501262664795
#
# EPOCH 192  (with max 500), loss: 0.03890909254550934
# Validation Loss: 0.00028923567151650786
# train time for 192 epochs, was 58.94912004470825
#
# EPOCH 194  (with max 500), loss: 0.03660651296377182
# Validation Loss: 0.00027577561559155583
# train time for 194 epochs, was 59.51023888587952
#
# EPOCH 196  (with max 500), loss: 0.030892319977283478
# Validation Loss: 0.00028123630909249187
# train time for 196 epochs, was 60.095876932144165
#
# EPOCH 198  (with max 500), loss: 0.0395762138068676
# Validation Loss: 0.00026634905952960253
# train time for 198 epochs, was 60.70643353462219
#
# EPOCH 200  (with max 500), loss: 0.03844141960144043
# Validation Loss: 0.00025604618713259697
# train time for 200 epochs, was 61.29712748527527
#
# EPOCH 200 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0200.pth
#
# EPOCH 202  (with max 500), loss: 0.029898488894104958
# Validation Loss: 0.00024059467250481248
# train time for 202 epochs, was 61.97940254211426
#
# EPOCH 204  (with max 500), loss: 0.03259066119790077
# Validation Loss: 0.0002442170516587794
# train time for 204 epochs, was 62.58616232872009
#
# EPOCH 206  (with max 500), loss: 0.03918404504656792
# Validation Loss: 0.00024462409783154726
# train time for 206 epochs, was 63.26294994354248
#
# EPOCH 208  (with max 500), loss: 0.0367899015545845
# Validation Loss: 0.00021798363013658673
# train time for 208 epochs, was 63.84583115577698
#
# EPOCH 210  (with max 500), loss: 0.034524861723184586
# Validation Loss: 0.00022374294348992407
# train time for 210 epochs, was 64.42855930328369
#
# EPOCH 212  (with max 500), loss: 0.03375088796019554
# Validation Loss: 0.00021388813911471516
# train time for 212 epochs, was 65.09863901138306
#
# EPOCH 214  (with max 500), loss: 0.0309242345392704
# Validation Loss: 0.00020953899365849793
# train time for 214 epochs, was 65.7707793712616
#
# EPOCH 216  (with max 500), loss: 0.03012217953801155
# Validation Loss: 0.00020380222122184932
# train time for 216 epochs, was 66.44091415405273
#
# EPOCH 218  (with max 500), loss: 0.03456144034862518
# Validation Loss: 0.0001912169682327658
# train time for 218 epochs, was 67.2046844959259
#
# EPOCH 220  (with max 500), loss: 0.02772710844874382
# Validation Loss: 0.0001728798379190266
# train time for 220 epochs, was 67.76883625984192
#
# EPOCH 222  (with max 500), loss: 0.02864154800772667
# Validation Loss: 0.00016233872156590223
# train time for 222 epochs, was 68.34527015686035
#
# EPOCH 224  (with max 500), loss: 0.023567937314510345
# Validation Loss: 0.00016058702021837234
# train time for 224 epochs, was 68.90668845176697
#
# EPOCH 226  (with max 500), loss: 0.025587860494852066
# Validation Loss: 0.00017363889492116868
# train time for 226 epochs, was 69.48389554023743
#
# EPOCH 228  (with max 500), loss: 0.023842254653573036
# Validation Loss: 0.00015681501827202737
# train time for 228 epochs, was 70.05145597457886
#
# EPOCH 230  (with max 500), loss: 0.02605079486966133
# Validation Loss: 0.00015359456301666796
# train time for 230 epochs, was 70.60757160186768
#
# EPOCH 232  (with max 500), loss: 0.023984422907233238
# Validation Loss: 0.00013819386367686093
# train time for 232 epochs, was 71.16380190849304
#
# EPOCH 234  (with max 500), loss: 0.025655997917056084
# Validation Loss: 0.00013917985779698938
# train time for 234 epochs, was 71.73785495758057
#
# EPOCH 236  (with max 500), loss: 0.023655569180846214
# Validation Loss: 0.0001359637826681137
# train time for 236 epochs, was 72.28623986244202
#
# EPOCH 238  (with max 500), loss: 0.029099158942699432
# Validation Loss: 0.00012869713827967644
# train time for 238 epochs, was 72.82484126091003
#
# EPOCH 240  (with max 500), loss: 0.022356927394866943
# Validation Loss: 0.00012864844757132232
# train time for 240 epochs, was 73.37174439430237
#
# EPOCH 242  (with max 500), loss: 0.026335451751947403
# Validation Loss: 0.00012233159213792533
# train time for 242 epochs, was 73.91550421714783
#
# EPOCH 244  (with max 500), loss: 0.02123446576297283
# Validation Loss: 0.00011808870476670563
# train time for 244 epochs, was 74.46553611755371
#
# EPOCH 246  (with max 500), loss: 0.022867875173687935
# Validation Loss: 0.00011958419054280967
# train time for 246 epochs, was 75.01075887680054
#
# EPOCH 248  (with max 500), loss: 0.024022575467824936
# Validation Loss: 0.00011109425395261496
# train time for 248 epochs, was 75.57471227645874
#
# EPOCH 250  (with max 500), loss: 0.021180778741836548
# Validation Loss: 0.00010964638204313815
# train time for 250 epochs, was 76.15751791000366
#
# EPOCH 250 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0250.pth
#
# EPOCH 252  (with max 500), loss: 0.02224857546389103
# Validation Loss: 0.00010633204510668293
# train time for 252 epochs, was 76.7444314956665
#
# EPOCH 254  (with max 500), loss: 0.021796800196170807
# Validation Loss: 0.0001052221268764697
# train time for 254 epochs, was 77.29304552078247
#
# EPOCH 256  (with max 500), loss: 0.018129335716366768
# Validation Loss: 0.00010127350833499804
# train time for 256 epochs, was 77.85943818092346
#
# EPOCH 258  (with max 500), loss: 0.01941828802227974
# Validation Loss: 9.749666787683964e-05
# train time for 258 epochs, was 78.41266965866089
#
# EPOCH 260  (with max 500), loss: 0.02266674116253853
# Validation Loss: 9.71861372818239e-05
# train time for 260 epochs, was 78.9559473991394
#
# EPOCH 262  (with max 500), loss: 0.02668718993663788
# Validation Loss: 8.774727757554501e-05
# train time for 262 epochs, was 79.50085377693176
#
# EPOCH 264  (with max 500), loss: 0.018606891855597496
# Validation Loss: 8.689576497999951e-05
# train time for 264 epochs, was 80.04407358169556
#
# EPOCH 266  (with max 500), loss: 0.022094644606113434
# Validation Loss: 8.988578338176012e-05
# train time for 266 epochs, was 80.58414268493652
#
# EPOCH 268  (with max 500), loss: 0.021309703588485718
# Validation Loss: 9.280839003622532e-05
# train time for 268 epochs, was 81.12654161453247
#
# EPOCH 270  (with max 500), loss: 0.019453397020697594
# Validation Loss: 8.408021676586941e-05
# train time for 270 epochs, was 81.66753077507019
#
# EPOCH 272  (with max 500), loss: 0.016119251027703285
# Validation Loss: 7.880660996306688e-05
# train time for 272 epochs, was 82.21116924285889
#
# EPOCH 274  (with max 500), loss: 0.018908407539129257
# Validation Loss: 7.853098213672638e-05
# train time for 274 epochs, was 82.76090717315674
#
# EPOCH 276  (with max 500), loss: 0.01865745149552822
# Validation Loss: 8.586981857661158e-05
# train time for 276 epochs, was 83.30186247825623
#
# EPOCH 278  (with max 500), loss: 0.01987902633845806
# Validation Loss: 7.775074482196942e-05
# train time for 278 epochs, was 83.88657212257385
#
# EPOCH 280  (with max 500), loss: 0.01738840527832508
# Validation Loss: 7.655242370674387e-05
# train time for 280 epochs, was 84.46260380744934
#
# EPOCH 282  (with max 500), loss: 0.020358970388770103
# Validation Loss: 7.118124631233513e-05
# train time for 282 epochs, was 85.01253294944763
#
# EPOCH 284  (with max 500), loss: 0.017106495797634125
# Validation Loss: 7.082097727106884e-05
# train time for 284 epochs, was 85.5584397315979
#
# EPOCH 286  (with max 500), loss: 0.015441819094121456
# Validation Loss: 7.289485802175477e-05
# train time for 286 epochs, was 86.11285948753357
#
# EPOCH 288  (with max 500), loss: 0.02041417919099331
# Validation Loss: 7.247807661769912e-05
# train time for 288 epochs, was 86.65722060203552
#
# EPOCH 290  (with max 500), loss: 0.019105076789855957
# Validation Loss: 6.705550185870379e-05
# train time for 290 epochs, was 87.20352172851562
#
# EPOCH 292  (with max 500), loss: 0.015663789585232735
# Validation Loss: 6.356091034831479e-05
# train time for 292 epochs, was 87.75063443183899
#
# EPOCH 294  (with max 500), loss: 0.017920032143592834
# Validation Loss: 6.060499435989186e-05
# train time for 294 epochs, was 88.31083869934082
#
# EPOCH 296  (with max 500), loss: 0.015194754116237164
# Validation Loss: 5.615319241769612e-05
# train time for 296 epochs, was 88.88015651702881
#
# EPOCH 298  (with max 500), loss: 0.023121926933526993
# Validation Loss: 5.7845354604069144e-05
# train time for 298 epochs, was 89.4419915676117
#
# EPOCH 300  (with max 500), loss: 0.014979584142565727
# Validation Loss: 5.664983837050386e-05
# train time for 300 epochs, was 89.97905564308167
#
# EPOCH 300 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0300.pth
#
# EPOCH 302  (with max 500), loss: 0.01543542742729187
# Validation Loss: 5.5680142395431176e-05
# train time for 302 epochs, was 90.61881589889526
#
# EPOCH 304  (with max 500), loss: 0.014463764615356922
# Validation Loss: 5.439117376226932e-05
# train time for 304 epochs, was 91.2395544052124
#
# EPOCH 306  (with max 500), loss: 0.01700722984969616
# Validation Loss: 5.5383541621267796e-05
# train time for 306 epochs, was 91.87845587730408
#
# EPOCH 308  (with max 500), loss: 0.016207896173000336
# Validation Loss: 5.334570596460253e-05
# train time for 308 epochs, was 92.42283463478088
#
# EPOCH 310  (with max 500), loss: 0.011227264069020748
# Validation Loss: 5.25767682120204e-05
# train time for 310 epochs, was 92.97234749794006
#
# EPOCH 312  (with max 500), loss: 0.013771070167422295
# Validation Loss: 5.100668204249814e-05
# train time for 312 epochs, was 93.56747174263
#
# EPOCH 314  (with max 500), loss: 0.015693210065364838
# Validation Loss: 4.9113426939584315e-05
# train time for 314 epochs, was 94.09631586074829
#
# EPOCH 316  (with max 500), loss: 0.017011400312185287
# Validation Loss: 4.802183684660122e-05
# train time for 316 epochs, was 94.62850999832153
#
# EPOCH 318  (with max 500), loss: 0.014600944705307484
# Validation Loss: 4.778122456627898e-05
# train time for 318 epochs, was 95.16264033317566
#
# EPOCH 320  (with max 500), loss: 0.013456474989652634
# Validation Loss: 4.5595588744618e-05
# train time for 320 epochs, was 95.6963996887207
#
# EPOCH 322  (with max 500), loss: 0.014569757506251335
# Validation Loss: 4.296808037906885e-05
# train time for 322 epochs, was 96.23065853118896
#
# EPOCH 324  (with max 500), loss: 0.013613720424473286
# Validation Loss: 4.164249185123481e-05
# train time for 324 epochs, was 96.76328587532043
#
# EPOCH 326  (with max 500), loss: 0.014615981839597225
# Validation Loss: 4.324052861193195e-05
# train time for 326 epochs, was 97.29513764381409
#
# EPOCH 328  (with max 500), loss: 0.01076306402683258
# Validation Loss: 4.18110575992614e-05
# train time for 328 epochs, was 97.86126160621643
#
# EPOCH 330  (with max 500), loss: 0.011555458419024944
# Validation Loss: 4.1922459786292166e-05
# train time for 330 epochs, was 98.41201376914978
#
# EPOCH 332  (with max 500), loss: 0.012131448835134506
# Validation Loss: 4.294671816751361e-05
# train time for 332 epochs, was 98.9523856639862
#
# EPOCH 334  (with max 500), loss: 0.013593731448054314
# Validation Loss: 4.189196624793112e-05
# train time for 334 epochs, was 99.51806449890137
#
# EPOCH 336  (with max 500), loss: 0.01298477966338396
# Validation Loss: 3.792145071201958e-05
# train time for 336 epochs, was 100.14756417274475
#
# EPOCH 338  (with max 500), loss: 0.013376761227846146
# Validation Loss: 3.678001667140052e-05
# train time for 338 epochs, was 100.71996259689331
#
# EPOCH 340  (with max 500), loss: 0.010555155575275421
# Validation Loss: 3.750836185645312e-05
# train time for 340 epochs, was 101.39367532730103
#
# EPOCH 342  (with max 500), loss: 0.013452764600515366
# Validation Loss: 3.622525036917068e-05
# train time for 342 epochs, was 102.14420247077942
#
# EPOCH 344  (with max 500), loss: 0.013934701681137085
# Validation Loss: 3.375207234057598e-05
# train time for 344 epochs, was 102.70368242263794
#
# EPOCH 346  (with max 500), loss: 0.011669744737446308
# Validation Loss: 3.340438343002461e-05
# train time for 346 epochs, was 103.30977439880371
#
# EPOCH 348  (with max 500), loss: 0.009666345082223415
# Validation Loss: 3.339027534821071e-05
# train time for 348 epochs, was 103.95732283592224
#
# EPOCH 350  (with max 500), loss: 0.011260127648711205
# Validation Loss: 3.3454598451498896e-05
# train time for 350 epochs, was 104.6091582775116
#
# EPOCH 350 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0350.pth
#
# EPOCH 352  (with max 500), loss: 0.015347730368375778
# Validation Loss: 3.255433330195956e-05
# train time for 352 epochs, was 105.2306227684021
#
# EPOCH 354  (with max 500), loss: 0.013145983219146729
# Validation Loss: 3.332125561428256e-05
# train time for 354 epochs, was 105.83403420448303
#
# EPOCH 356  (with max 500), loss: 0.011242184787988663
# Validation Loss: 3.255551200709306e-05
# train time for 356 epochs, was 106.45194888114929
#
# EPOCH 358  (with max 500), loss: 0.014232877641916275
# Validation Loss: 3.206486508133821e-05
# train time for 358 epochs, was 107.05912446975708
#
# EPOCH 360  (with max 500), loss: 0.011655296199023724
# Validation Loss: 3.055288107134402e-05
# train time for 360 epochs, was 107.84565663337708
#
# EPOCH 362  (with max 500), loss: 0.011929797939956188
# Validation Loss: 3.0646238883491606e-05
# train time for 362 epochs, was 108.3979549407959
#
# EPOCH 364  (with max 500), loss: 0.012491009198129177
# Validation Loss: 2.838286673068069e-05
# train time for 364 epochs, was 108.96322226524353
#
# EPOCH 366  (with max 500), loss: 0.012633023783564568
# Validation Loss: 2.8243681299500167e-05
# train time for 366 epochs, was 109.514728307724
#
# EPOCH 368  (with max 500), loss: 0.011260480619966984
# Validation Loss: 2.8322223442955874e-05
# train time for 368 epochs, was 110.08132576942444
#
# EPOCH 370  (with max 500), loss: 0.01074646320194006
# Validation Loss: 3.0072700610617176e-05
# train time for 370 epochs, was 110.64272904396057
#
# EPOCH 372  (with max 500), loss: 0.010854066349565983
# Validation Loss: 2.951743226731196e-05
# train time for 372 epochs, was 111.20431447029114
#
# EPOCH 374  (with max 500), loss: 0.013604922220110893
# Validation Loss: 2.8534950615721755e-05
# train time for 374 epochs, was 111.74486446380615
#
# EPOCH 376  (with max 500), loss: 0.009035149589180946
# Validation Loss: 2.6541281840763986e-05
# train time for 376 epochs, was 112.28841280937195
#
# EPOCH 378  (with max 500), loss: 0.012425314635038376
# Validation Loss: 2.7406094886828214e-05
# train time for 378 epochs, was 112.83290219306946
#
# EPOCH 380  (with max 500), loss: 0.012383470311760902
# Validation Loss: 2.5109355192398652e-05
# train time for 380 epochs, was 113.386638879776
#
# EPOCH 382  (with max 500), loss: 0.01046929880976677
# Validation Loss: 2.5603776521165855e-05
# train time for 382 epochs, was 113.93409585952759
#
# EPOCH 384  (with max 500), loss: 0.014641442336142063
# Validation Loss: 2.5774494133656844e-05
# train time for 384 epochs, was 114.48078107833862
#
# EPOCH 386  (with max 500), loss: 0.008965905755758286
# Validation Loss: 2.646504799486138e-05
# train time for 386 epochs, was 115.01943612098694
#
# EPOCH 388  (with max 500), loss: 0.010035954415798187
# Validation Loss: 2.451994441798888e-05
# train time for 388 epochs, was 115.56754279136658
#
# EPOCH 390  (with max 500), loss: 0.010281424038112164
# Validation Loss: 2.3938180675031617e-05
# train time for 390 epochs, was 116.12330722808838
#
# EPOCH 392  (with max 500), loss: 0.010095960460603237
# Validation Loss: 2.3251341190189123e-05
# train time for 392 epochs, was 116.69049167633057
#
# EPOCH 394  (with max 500), loss: 0.00968879647552967
# Validation Loss: 2.261245572299231e-05
# train time for 394 epochs, was 117.23023962974548
#
# EPOCH 396  (with max 500), loss: 0.010265504941344261
# Validation Loss: 2.192578904214315e-05
# train time for 396 epochs, was 117.77559804916382
#
# EPOCH 398  (with max 500), loss: 0.00929878931492567
# Validation Loss: 2.207652505603619e-05
# train time for 398 epochs, was 118.32495427131653
#
# EPOCH 400  (with max 500), loss: 0.011455218307673931
# Validation Loss: 2.170924017264042e-05
# train time for 400 epochs, was 118.91990375518799
#
# EPOCH 400 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0400.pth
#
# EPOCH 402  (with max 500), loss: 0.009546712972223759
# Validation Loss: 2.0864496036665514e-05
# train time for 402 epochs, was 119.54504632949829
#
# EPOCH 404  (with max 500), loss: 0.009942643344402313
# Validation Loss: 2.0755382138304412e-05
# train time for 404 epochs, was 120.16254258155823
#
# EPOCH 406  (with max 500), loss: 0.009744343347847462
# Validation Loss: 2.0874529582215473e-05
# train time for 406 epochs, was 120.80780482292175
#
# EPOCH 408  (with max 500), loss: 0.0073029231280088425
# Validation Loss: 2.0918298105243593e-05
# train time for 408 epochs, was 121.3782114982605
#
# EPOCH 410  (with max 500), loss: 0.014293280430138111
# Validation Loss: 2.1464202291099355e-05
# train time for 410 epochs, was 121.94333863258362
#
# EPOCH 412  (with max 500), loss: 0.008246183395385742
# Validation Loss: 2.0151497665210627e-05
# train time for 412 epochs, was 122.54167866706848
#
# EPOCH 414  (with max 500), loss: 0.010544479824602604
# Validation Loss: 2.0733477867906913e-05
# train time for 414 epochs, was 123.23517632484436
#
# EPOCH 416  (with max 500), loss: 0.00858567375689745
# Validation Loss: 1.8797463781083934e-05
# train time for 416 epochs, was 123.77942633628845
#
# EPOCH 418  (with max 500), loss: 0.008639724925160408
# Validation Loss: 1.8956166968564503e-05
# train time for 418 epochs, was 124.37025141716003
#
# EPOCH 420  (with max 500), loss: 0.010551147162914276
# Validation Loss: 1.9637420336948708e-05
# train time for 420 epochs, was 124.98791766166687
#
# EPOCH 422  (with max 500), loss: 0.00993417203426361
# Validation Loss: 1.9876206351909786e-05
# train time for 422 epochs, was 125.55260944366455
#
# EPOCH 424  (with max 500), loss: 0.011618709191679955
# Validation Loss: 2.0535599105642177e-05
# train time for 424 epochs, was 126.10349130630493
#
# EPOCH 426  (with max 500), loss: 0.009246866218745708
# Validation Loss: 1.8192768038716167e-05
# train time for 426 epochs, was 126.65172576904297
#
# EPOCH 428  (with max 500), loss: 0.007465214468538761
# Validation Loss: 1.8177383026340976e-05
# train time for 428 epochs, was 127.19487690925598
#
# EPOCH 430  (with max 500), loss: 0.008617912419140339
# Validation Loss: 1.8442384316585958e-05
# train time for 430 epochs, was 127.7348096370697
#
# EPOCH 432  (with max 500), loss: 0.008242391981184483
# Validation Loss: 1.9200022506993264e-05
# train time for 432 epochs, was 128.2791244983673
#
# EPOCH 434  (with max 500), loss: 0.007756873965263367
# Validation Loss: 1.7795677194953896e-05
# train time for 434 epochs, was 128.8939356803894
#
# EPOCH 436  (with max 500), loss: 0.007073597051203251
# Validation Loss: 1.75088152900571e-05
# train time for 436 epochs, was 129.48019862174988
#
# EPOCH 438  (with max 500), loss: 0.008828735910356045
# Validation Loss: 1.7478170775575563e-05
# train time for 438 epochs, was 130.06567430496216
#
# EPOCH 440  (with max 500), loss: 0.00831781979650259
# Validation Loss: 1.6216461517615244e-05
# train time for 440 epochs, was 130.6972451210022
#
# EPOCH 442  (with max 500), loss: 0.00793067179620266
# Validation Loss: 1.5827867173356935e-05
# train time for 442 epochs, was 131.30585289001465
#
# EPOCH 444  (with max 500), loss: 0.00911444891244173
# Validation Loss: 1.4762276805413421e-05
# train time for 444 epochs, was 131.96101093292236
#
# EPOCH 446  (with max 500), loss: 0.008532744832336903
# Validation Loss: 1.5527464711340144e-05
# train time for 446 epochs, was 132.55631041526794
#
# EPOCH 448  (with max 500), loss: 0.006667055655270815
# Validation Loss: 1.593201159266755e-05
# train time for 448 epochs, was 133.12603497505188
#
# EPOCH 450  (with max 500), loss: 0.009314671158790588
# Validation Loss: 1.554889968247153e-05
# train time for 450 epochs, was 133.71382522583008
#
# EPOCH 450 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0450.pth
#
# EPOCH 452  (with max 500), loss: 0.008067978546023369
# Validation Loss: 1.5899022400844842e-05
# train time for 452 epochs, was 134.32484030723572
#
# EPOCH 454  (with max 500), loss: 0.007964873686432838
# Validation Loss: 1.4666928109363653e-05
# train time for 454 epochs, was 134.89629220962524
#
# EPOCH 456  (with max 500), loss: 0.009885172359645367
# Validation Loss: 1.4530491171171889e-05
# train time for 456 epochs, was 135.4529321193695
#
# EPOCH 458  (with max 500), loss: 0.009869406931102276
# Validation Loss: 1.5148187230806798e-05
# train time for 458 epochs, was 136.05706763267517
#
# EPOCH 460  (with max 500), loss: 0.007508790120482445
# Validation Loss: 1.389268618368078e-05
# train time for 460 epochs, was 136.70354843139648
#
# EPOCH 462  (with max 500), loss: 0.009414972737431526
# Validation Loss: 1.3822096661897376e-05
# train time for 462 epochs, was 137.31232714653015
#
# EPOCH 464  (with max 500), loss: 0.007546492852270603
# Validation Loss: 1.3873306670575403e-05
# train time for 464 epochs, was 137.9189064502716
#
# EPOCH 466  (with max 500), loss: 0.0077496301382780075
# Validation Loss: 1.3755716281593777e-05
# train time for 466 epochs, was 138.47405815124512
#
# EPOCH 468  (with max 500), loss: 0.0072167101316154
# Validation Loss: 1.3315868272911757e-05
# train time for 468 epochs, was 139.0887668132782
#
# EPOCH 470  (with max 500), loss: 0.004491932224482298
# Validation Loss: 1.2789402717316989e-05
# train time for 470 epochs, was 139.64875411987305
#
# EPOCH 472  (with max 500), loss: 0.007084399461746216
# Validation Loss: 1.261501711269375e-05
# train time for 472 epochs, was 140.28558778762817
#
# EPOCH 474  (with max 500), loss: 0.009249553084373474
# Validation Loss: 1.3352100722840987e-05
# train time for 474 epochs, was 140.84084582328796
#
# EPOCH 476  (with max 500), loss: 0.008104132488369942
# Validation Loss: 1.4024190022610128e-05
# train time for 476 epochs, was 141.40738153457642
#
# EPOCH 478  (with max 500), loss: 0.008646931499242783
# Validation Loss: 1.3967774066259153e-05
# train time for 478 epochs, was 141.9664649963379
#
# EPOCH 480  (with max 500), loss: 0.007434742990881205
# Validation Loss: 1.5390805856441148e-05
# train time for 480 epochs, was 142.56811428070068
#
# EPOCH 482  (with max 500), loss: 0.006730141118168831
# Validation Loss: 1.4702797670906875e-05
# train time for 482 epochs, was 143.2096402645111
#
# EPOCH 484  (with max 500), loss: 0.006309484131634235
# Validation Loss: 1.2444595995475538e-05
# train time for 484 epochs, was 143.9838740825653
#
# EPOCH 486  (with max 500), loss: 0.007961181923747063
# Validation Loss: 1.21091325127054e-05
# train time for 486 epochs, was 144.57181191444397
#
# EPOCH 488  (with max 500), loss: 0.008726831525564194
# Validation Loss: 1.217380486195907e-05
# train time for 488 epochs, was 145.20583248138428
#
# EPOCH 490  (with max 500), loss: 0.006850983947515488
# Validation Loss: 1.320921910519246e-05
# train time for 490 epochs, was 145.83116793632507
#
# EPOCH 492  (with max 500), loss: 0.006346544250845909
# Validation Loss: 1.2597417480719741e-05
# train time for 492 epochs, was 146.40116477012634
#
# EPOCH 494  (with max 500), loss: 0.005997930653393269
# Validation Loss: 1.2804432117263786e-05
# train time for 494 epochs, was 146.980477809906
#
# EPOCH 496  (with max 500), loss: 0.008845762349665165
# Validation Loss: 1.2429809430614114e-05
# train time for 496 epochs, was 147.57664966583252
#
# EPOCH 498  (with max 500), loss: 0.007522142492234707
# Validation Loss: 1.1523499779286794e-05
# train time for 498 epochs, was 148.17179203033447
#
# EPOCH 500  (with max 500), loss: 0.006468040402978659
# Validation Loss: 1.0725834727054462e-05
# train time for 500 epochs, was 148.83674263954163
#
# EPOCH 500 save model to : runs/med_test_mine_01_params_added/out.e256.l2.h8_chkpt_0500.pth
#
# train time for 500 epochs, was 148.86477661132812
# loss  =  0.006468040402978659

# %%
#just check that inference attention mask will look right
#Actually, the inference mask can be None since we are using a context window only as long as the maximum look-back in the training mask
# thats why taking the mask with :TI is upper-triangular. Longer dims would show a banded mask again.
foo=mask[:Ti, :Ti]
foo
# Out:
# tensor([[0., -inf, -inf,  ..., -inf, -inf, -inf],
#         [0., 0., -inf,  ..., -inf, -inf, -inf],
#         [0., 0., 0.,  ..., -inf, -inf, -inf],
#         ...,
#         [0., 0., 0.,  ..., 0., -inf, -inf],
#         [0., 0., 0.,  ..., 0., 0., -inf],
#         [0., 0., 0.,  ..., 0., 0., 0.]])

# %% [markdown]
# ### <font color='blue'> Use Inference.Decode.ipynb to see and hear your generated audio
# </font>
